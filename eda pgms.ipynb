# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Upload your Excel file
from google.colab import files
uploaded = files.upload()
print("First 5 rows:\n", df.head())

# Read Excel file
df = pd.read_excel("movies_data.xlsx")
df.head()
# Out:
#      <input type="file" id="files-60bbd07d-5095-401b-ba08-bc119f0f2436" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-60bbd07d-5095-401b-ba08-bc119f0f2436">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   MovieID                  10 non-null     int64
#  1   Title                    10 non-null     object
#  2   Genre                    10 non-null     object
#  3   Director                 10 non-null     object
#  4   ReleaseYear              10 non-null     int64
#  5   Rating                   10 non-null     float64
#  6   BoxOffice (in millions)  10 non-null     float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 692.0+ bytes

# %%
plt.figure(figsize=(8,5))
plt.hist(df['Rating'], bins=5, color='skyblue', edgecolor='black')
plt.title("Distribution of Movie Ratings")
plt.xlabel("Rating")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df['BoxOffice (in millions)'], bins=5, color='lightgreen', edgecolor='black')
plt.title("Distribution of Box Office Revenue")
plt.xlabel("Box Office (in millions)")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='Rating', y='BoxOffice (in millions)', hue='Genre', s=100)
plt.title("Rating vs Box Office Revenue")
plt.xlabel("Rating")
plt.ylabel("Box Office (in millions)")
plt.show()

# %%
df.describe()
# Out:
#         MovieID  ReleaseYear     Rating  BoxOffice (in millions)
# count  10.00000    10.000000  10.000000                 10.00000
# mean    5.50000  1997.900000   8.830000                545.97000
# std     3.02765    11.761047   0.275076                344.10821
# min     1.00000  1972.000000   8.500000                 28.30000
# 25%     3.25000  1994.000000   8.625000                275.55000
# 50%     5.50000  1996.500000   8.800000                570.50000
# 75%     7.75000  2006.000000   8.975000                791.97500
# max    10.00000  2014.000000   9.300000               1004.60000

# %%
df['Genre'].value_counts()
# Out:
# Genre
# Sci-Fi       3
# Drama        2
# Crime        2
# Action       2
# Animation    1
# Name: count, dtype: int64

# %%
df.groupby('Director')['Rating'].mean()
# Out:
# Director
# Christopher Nolan       8.8
# Francis Ford Coppola    9.2
# Frank Darabont          9.3
# Lana Wachowski          8.7
# Quentin Tarantino       8.9
# Ridley Scott            8.5
# Robert Zemeckis         8.8
# Roger Allers            8.5
# Name: Rating, dtype: float64
